# %%
import numpy as np
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %%
def data_prettify(data_raw, teams_file_name):
    data = pd.DataFrame()

    data['match_url'] = data_raw['Original_URL']
    data['player'] = data_raw['Title']
    data['position'] = data_raw['col12lg21']
    data['rating'] = data_raw['rating']

    data['rating'] = data['rating'].apply(lambda x: np.nan if pd.isna(x) or x == '-' else float(str(x)))
    data['position'] = data['position'].apply(lambda x: np.nan if pd.isna(x) else x[2:].strip())

    teams = set()
    file = open(teams_file_name, 'r')
    for line in file:
        teams.add(line.strip())
    teams.remove('P')

    home_team = []
    away_team = []
    for i in range(len(data)):
        url = data.iloc[i]['match_url']
        home, away = np.nan, np.nan
        for team in teams:
            index = url.find(team.replace(' ', '-'))
            if index >= 0:
                if index + len(team) == len(url):
                    away_team.append(team)
                else:
                    home_team.append(team)

    data['home_team'] = home_team
    data['away_team'] = away_team

    return data

# %% [markdown]
# England-Premier-League.

# %%
data_raw = pd.concat([
    pd.read_csv('England-Premier-League_player_ratings_part_1.csv'),
    pd.read_csv('England-Premier-League_player_ratings_part_1(1).csv'),
    pd.read_csv('England-Premier-League_player_ratings_part_2.csv'),
    pd.read_csv('England-Premier-League_player_ratings_part_2(1).csv'),
    pd.read_csv('England-Premier-League_player_ratings_part_3.csv'),
    pd.read_csv('England-Premier-League_player_ratings_part_3(1).csv'),
    pd.read_csv('England-Premier-League_player_ratings_part_3(2).csv')
], axis=0)

# %%
file = 'England-Premier-League_teams.txt'

# %%
data = data_prettify(data_raw, file)

# %%
data.head()
# Out:
#                                            match_url          player position  \
# 0  https://1xbet.whoscored.com/Matches/829783/Liv...     Boaz Myhill       GK
# 1  https://1xbet.whoscored.com/Matches/829783/Liv...    Craig Dawson       DR
# 2  https://1xbet.whoscored.com/Matches/829783/Liv...    Jonas Olsson       DC
# 3  https://1xbet.whoscored.com/Matches/829783/Liv...  Gareth McAuley       DC
# 4  https://1xbet.whoscored.com/Matches/829783/Liv...  Joleon Lescott       DL
#
#    rating             home_team away_team
# 0    7.43  West Bromwich Albion   Chelsea
# 1    7.92  West Bromwich Albion   Chelsea
# 2    6.85  West Bromwich Albion   Chelsea
# 3    6.79  West Bromwich Albion   Chelsea
# 4    7.27  West Bromwich Albion   Chelsea

# %%
data.to_csv('England-Premier-League_ratings.csv')

# %% [markdown]
# Spain-LaLiga.

# %%
data_raw = pd.concat([
    pd.read_csv('Spain-LaLiga_player_ratings_part_1.csv'),
    pd.read_csv('Spain-LaLiga_player_ratings_part_1(1).csv'),
    pd.read_csv('Spain-LaLiga_player_ratings_part_2.csv'),
    pd.read_csv('Spain-LaLiga_player_ratings_part_2(1).csv'),
    pd.read_csv('Spain-LaLiga_player_ratings_part_3.csv'),
    pd.read_csv('Spain-LaLiga_player_ratings_part_3(1).csv'),
    pd.read_csv('Spain-LaLiga_player_ratings_part_3(2).csv'),
    pd.read_csv('Spain-LaLiga_player_ratings_part_3(3).csv')
], axis=0)

# %%
file = 'Spain-LaLiga_teams.txt'

# %%
data = data_prettify(data_raw, file)

# %%
data.head()
# Out:
#                                            match_url         player position  \
# 0  https://1xbet.whoscored.com/Matches/862242/Liv...   Diego Mariño       GK
# 1  https://1xbet.whoscored.com/Matches/862242/Liv...    Pedro López       DR
# 2  https://1xbet.whoscored.com/Matches/862242/Liv...  Loukas Vyntra       DC
# 3  https://1xbet.whoscored.com/Matches/862242/Liv...       Juanfran       DC
# 4  https://1xbet.whoscored.com/Matches/862242/Liv...  David Navarro       DC
#
#    rating home_team away_team
# 0    8.78   Levante     Elche
# 1    6.96   Levante     Elche
# 2    6.86   Levante     Elche
# 3    6.93   Levante     Elche
# 4    6.80   Levante     Elche

# %%
data.to_csv('Spain-LaLiga_ratings.csv')

# %% [markdown]
# Italy-Serie-A.

# %%
data_raw = pd.concat([
    pd.read_csv('Italy-Serie-A_player_ratings_part_1.csv'),
    pd.read_csv('Italy-Serie-A_player_ratings_part_1(1).csv'),
    pd.read_csv('Italy-Serie-A_player_ratings_part_1(2).csv'),
    pd.read_csv('Italy-Serie-A_player_ratings_part_2.csv'),
    pd.read_csv('Italy-Serie-A_player_ratings_part_2(1).csv'),
    pd.read_csv('Italy-Serie-A_player_ratings_part_2(2).csv'),
    pd.read_csv('Italy-Serie-A_player_ratings_part_3.csv'),
    pd.read_csv('Italy-Serie-A_player_ratings_part_3(1).csv'),
    pd.read_csv('Italy-Serie-A_player_ratings_part_3(2).csv')
], axis=0)

# %%
file = 'Italy-Serie-A_teams.txt'

# %%
data = data_prettify(data_raw, file)

# %%
data.head()
# Out:
#                                            match_url               player  \
# 0  https://1xbet.whoscored.com/Matches/866178/Liv...   Federico Marchetti
# 1  https://1xbet.whoscored.com/Matches/866178/Liv...          Dusan Basta
# 2  https://1xbet.whoscored.com/Matches/866178/Liv...  Santiago Gentiletti
# 3  https://1xbet.whoscored.com/Matches/866178/Liv...       Stefan de Vrij
# 4  https://1xbet.whoscored.com/Matches/866178/Liv...          Senad Lulic
#
#   position  rating home_team away_team
# 0       GK    5.62     Lazio      Roma
# 1       DR    6.53     Lazio      Roma
# 2       DC    6.07     Lazio      Roma
# 3       DC    6.56     Lazio      Roma
# 4       DL    6.38     Lazio      Roma

# %%
data.to_csv('Italy-Serie-A_ratings.csv')

# %% [markdown]
# Germany-Bundesliga.

# %%
data_raw = pd.concat([
    pd.read_csv('Germany-Bundesliga_player_ratings_part_1.csv'),
    pd.read_csv('Germany-Bundesliga_player_ratings_part_1(1).csv'),
    pd.read_csv('Germany-Bundesliga_player_ratings_part_1(2).csv'),
    pd.read_csv('Germany-Bundesliga_player_ratings_part_2.csv'),
    pd.read_csv('Germany-Bundesliga_player_ratings_part_2(1).csv'),
    pd.read_csv('Germany-Bundesliga_player_ratings_part_2(2).csv')
], axis=0)

# %%
file = 'Germany-Bundesliga_teams.txt'

# %%
data = data_prettify(data_raw, file)

# %%
data.head()
# Out:
#                                            match_url          player position  \
# 0  https://1xbet.whoscored.com/Matches/834866/Liv...    Manuel Neuer       GK
# 1  https://1xbet.whoscored.com/Matches/834866/Liv...         Rafinha       DR
# 2  https://1xbet.whoscored.com/Matches/834866/Liv...           Dante       DC
# 3  https://1xbet.whoscored.com/Matches/834866/Liv...  Jérôme Boateng       DC
# 4  https://1xbet.whoscored.com/Matches/834866/Liv...     Juan Bernat       DL
#
#    rating      home_team away_team
# 0    7.65  Bayern Munich  Mainz 05
# 1    7.20  Bayern Munich  Mainz 05
# 2    8.06  Bayern Munich  Mainz 05
# 3    7.48  Bayern Munich  Mainz 05
# 4    7.73  Bayern Munich  Mainz 05

# %%
data.to_csv('Germany-Bundesliga_ratings.csv')

# %% [markdown]
# France-Ligue-1.

# %%
data_raw = pd.concat([
    pd.read_csv('France-Ligue-1_player_ratings_part_1.csv'),
    pd.read_csv('France-Ligue-1_player_ratings_part_1(1).csv'),
    pd.read_csv('France-Ligue-1_player_ratings_part_2.csv'),
    pd.read_csv('France-Ligue-1_player_ratings_part_2(1).csv'),
    pd.read_csv('France-Ligue-1_player_ratings_part_3.csv'),
    pd.read_csv('France-Ligue-1_player_ratings_part_3(1).csv'),
    pd.read_csv('France-Ligue-1_player_ratings_part_3(2).csv')
], axis=0)

# %%
file = 'France-Ligue-1_teams.txt'

# %%
data = data_prettify(data_raw, file)

# %%
data.head()
# Out:
#                                            match_url           player  \
# 0  https://1xbet.whoscored.com/Matches/824549/Liv...  Cédric Carrasso
# 1  https://1xbet.whoscored.com/Matches/824549/Liv...          Mariano
# 2  https://1xbet.whoscored.com/Matches/824549/Liv...   Grégory Sertic
# 3  https://1xbet.whoscored.com/Matches/824549/Liv...      Lamine Sané
# 4  https://1xbet.whoscored.com/Matches/824549/Liv...  Nicolas Pallois
#
#   position  rating home_team    away_team
# 0       GK    6.13  Bordeaux  Montpellier
# 1       DR    7.92  Bordeaux  Montpellier
# 2       DC    7.71  Bordeaux  Montpellier
# 3       DC    7.07  Bordeaux  Montpellier
# 4       DL    6.73  Bordeaux  Montpellier

# %%
data.to_csv('France-Ligue-1_ratings.csv')
